# %%
import pandas as pd
import numpy as np
import sqlalchemy 
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func, inspect

# %%
u_csv = '~/Desktop/ETL_project/Data_for_ETL_project_raw/urbanization-state.csv'

urb_df = pd.read_csv(u_csv)

urb_df.head(25)
# Out:
#                    state  urbanindex
# 0                Alabama    9.605935
# 1                 Alaska    8.735964
# 2         American Samoa   11.085930
# 3                Arizona   11.299710
# 4               Arkansas    9.259444
# 5             California   12.190280
# 6               Colorado   11.154450
# 7            Connecticut   11.409680
# 8               Delaware   11.009990
# 9   District of Columbia   13.440570
# 10               Florida   11.464840
# 11               Georgia   10.552330
# 12                  Guam   11.085930
# 13                Hawaii   11.086210
# 14                 Idaho    9.593634
# 15              Illinois   11.623720
# 16               Indiana   10.410500
# 17                  Iowa    9.593525
# 18                Kansas   10.120440
# 19              Kentucky    9.789536
# 20             Louisiana   10.175180
# 21                 Maine    9.037091
# 22              Maryland   11.711050
# 23         Massachusetts   11.839730
# ...

# %%
d_csv = '~/Desktop/ETL_project/Data_for_ETL_project_raw/2015_Racial_Data_State_clean.csv'

demo_df = pd.read_csv(d_csv)

demo_df.head(52)
# Out:
#                 Location  White  Black  Hispanic  Asian  \
# 0          United States   0.61   0.12      0.18   0.06
# 1                Alabama   0.65   0.27      0.04    NaN
# 2                 Alaska   0.58   0.03      0.06   0.07
# 3                Arizona   0.51   0.04      0.37   0.03
# 4               Arkansas   0.74   0.15      0.07   0.02
# 5             California   0.39   0.06      0.38   0.15
# 6               Colorado   0.69   0.04      0.21   0.03
# 7            Connecticut   0.70   0.09      0.15   0.04
# 8               Delaware   0.63   0.21      0.10   0.04
# 9   District of Columbia   0.37   0.46      0.11   0.05
# 10               Florida   0.54   0.16      0.26   0.02
# 11               Georgia   0.52   0.31      0.10   0.05
# 12                Hawaii   0.19   0.02      0.10   0.39
# 13                 Idaho   0.84   0.01      0.13   0.01
# 14              Illinois   0.63   0.13      0.16   0.06
# 15               Indiana   0.80   0.09      0.08   0.02
# ...

# %%
e_csv = '~/Desktop/ETL_project/Data_for_ETL_project_raw/elasticity-by-state_clean_key.csv'

elas_df = pd.read_csv(e_csv)

elas_df.head(25)
# Out:
#                    state  elasticity
# 0                 Alaska        1.16
# 1                Alabama        0.89
# 2               Arkansas        1.00
# 3                Arizona        1.05
# 4             California        0.94
# 5               Colorado        1.07
# 6            Connecticut        0.99
# 7   District of Columbia        0.80
# 8               Delaware        0.93
# 9                Florida        1.03
# 10               Georgia        0.90
# 11                Hawaii        1.07
# 12                  Iowa        1.08
# 13                 Idaho        1.12
# 14              Illinois        1.01
# 15               Indiana        0.99
# 16                Kansas        1.00
# 17              Kentucky        0.94
# 18             Louisiana        0.96
# 19         Massachusetts        1.15
# 20              Maryland        0.96
# 21                 Maine        1.13
# 22              Michigan        1.07
# 23             Minnesota        1.03
# ...

# %%
# drop united states from the first df

demo_df.drop(demo_df.index[0], inplace = True)

demo_df
# Out:
#                 Location  White  Black  Hispanic  Asian  \
# 1                Alabama   0.65   0.27      0.04    NaN
# 2                 Alaska   0.58   0.03      0.06   0.07
# 3                Arizona   0.51   0.04      0.37   0.03
# 4               Arkansas   0.74   0.15      0.07   0.02
# 5             California   0.39   0.06      0.38   0.15
# 6               Colorado   0.69   0.04      0.21   0.03
# 7            Connecticut   0.70   0.09      0.15   0.04
# 8               Delaware   0.63   0.21      0.10   0.04
# 9   District of Columbia   0.37   0.46      0.11   0.05
# 10               Florida   0.54   0.16      0.26   0.02
# 11               Georgia   0.52   0.31      0.10   0.05
# 12                Hawaii   0.19   0.02      0.10   0.39
# 13                 Idaho   0.84   0.01      0.13   0.01
# 14              Illinois   0.63   0.13      0.16   0.06
# 15               Indiana   0.80   0.09      0.08   0.02
# 16                  Iowa   0.85   0.03      0.08   0.02
# ...

# %%
#drop the total column

demo_df.drop(demo_df.columns[8], axis = 1, inplace = True)

demo_df
# Out:
#                 Location  White  Black  Hispanic  Asian  \
# 1                Alabama   0.65   0.27      0.04    NaN
# 2                 Alaska   0.58   0.03      0.06   0.07
# 3                Arizona   0.51   0.04      0.37   0.03
# 4               Arkansas   0.74   0.15      0.07   0.02
# 5             California   0.39   0.06      0.38   0.15
# 6               Colorado   0.69   0.04      0.21   0.03
# 7            Connecticut   0.70   0.09      0.15   0.04
# 8               Delaware   0.63   0.21      0.10   0.04
# 9   District of Columbia   0.37   0.46      0.11   0.05
# 10               Florida   0.54   0.16      0.26   0.02
# 11               Georgia   0.52   0.31      0.10   0.05
# 12                Hawaii   0.19   0.02      0.10   0.39
# 13                 Idaho   0.84   0.01      0.13   0.01
# 14              Illinois   0.63   0.13      0.16   0.06
# 15               Indiana   0.80   0.09      0.08   0.02
# 16                  Iowa   0.85   0.03      0.08   0.02
# ...

# %%
#Get rid of territories in in urbanization data

combine_df = pd.merge(urb_df, elas_df, on='state')

combine_df.head(51)
# Out:
#                    state  urbanindex  elasticity
# 0                Alabama    9.605935        0.89
# 1                 Alaska    8.735964        1.16
# 2                Arizona   11.299710        1.05
# 3               Arkansas    9.259444        1.00
# 4             California   12.190280        0.94
# 5               Colorado   11.154450        1.07
# 6            Connecticut   11.409680        0.99
# 7               Delaware   11.009990        0.93
# 8   District of Columbia   13.440570        0.80
# 9                Florida   11.464840        1.03
# 10               Georgia   10.552330        0.90
# 11                Hawaii   11.086210        1.07
# 12                 Idaho    9.593634        1.12
# 13              Illinois   11.623720        1.01
# 14               Indiana   10.410500        0.99
# 15                  Iowa    9.593525        1.08
# 16                Kansas   10.120440        1.00
# 17              Kentucky    9.789536        0.94
# ...

# %%
#getting cleaned urb_df back out by splitting it from combine_df

urb2_df = combine_df[['state', 'urbanindex']].copy()

urb2_df.head(51)
# Out:
#                    state  urbanindex
# 0                Alabama    9.605935
# 1                 Alaska    8.735964
# 2                Arizona   11.299710
# 3               Arkansas    9.259444
# 4             California   12.190280
# 5               Colorado   11.154450
# 6            Connecticut   11.409680
# 7               Delaware   11.009990
# 8   District of Columbia   13.440570
# 9                Florida   11.464840
# 10               Georgia   10.552330
# 11                Hawaii   11.086210
# 12                 Idaho    9.593634
# 13              Illinois   11.623720
# 14               Indiana   10.410500
# 15                  Iowa    9.593525
# 16                Kansas   10.120440
# 17              Kentucky    9.789536
# 18             Louisiana   10.175180
# 19                 Maine    9.037091
# 20              Maryland   11.711050
# 21         Massachusetts   11.839730
# 22              Michigan   10.805590
# 23             Minnesota   10.456840
# ...

# %%
#rds_connection_string = "postgres:J@3eaze1@localhost:5432/ByState.db"
#

# %%
#engine = create_engine(f'postgresql://{rds_connection_string}')

# %%
#engine.table_names()

# %%
#Write dataframes to csv for import into postgresql

# %%
demo_df.to_csv('~\Desktop\ETL_project\state_demo_cleaned.csv', index = False)

# %%
urb2_df.to_csv(r'~\Desktop\ETL_project\urbanization_cleaned.csv', index = False)

# %%
urb3_df = combine_df[['state', 'elasticity']].copy()

urb3_df.head(20)
# Out:
#                    state  elasticity
# 0                Alabama        0.89
# 1                 Alaska        1.16
# 2                Arizona        1.05
# 3               Arkansas        1.00
# 4             California        0.94
# 5               Colorado        1.07
# 6            Connecticut        0.99
# 7               Delaware        0.93
# 8   District of Columbia        0.80
# 9                Florida        1.03
# 10               Georgia        0.90
# 11                Hawaii        1.07
# 12                 Idaho        1.12
# 13              Illinois        1.01
# 14               Indiana        0.99
# 15                  Iowa        1.08
# 16                Kansas        1.00
# 17              Kentucky        0.94
# 18             Louisiana        0.96
# 19                 Maine        1.13

# %%
urb3_df.to_csv(r'~\Desktop\ETL_project\elas_cleaned.csv', index = False)
